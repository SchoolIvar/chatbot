# %% [markdown]
# <a href="https://colab.research.google.com/github/SchoolIvar/chatbot/blob/main/gemeni_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade google-generativeai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show google-generativeai
# Out:
# Name: google-generativeai
# Version: 0.8.5
# Summary: Google Generative AI High level API client library and tools.
# Home-page: https://github.com/google/generative-ai-python
# Author: Google LLC
# Author-email: googleapis-packages@google.com
# License: Apache 2.0
# Location: /Users/ivarsmit/anaconda3/lib/python3.11/site-packages
# Requires: google-ai-generativelanguage, google-api-core, google-api-python-client, google-auth, protobuf, pydantic, tqdm, typing-extensions
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
Mini‑Gemini chatbot (CLI) – met API‑sleutel hard‑gecode.
"""

import sys
import google.generativeai as genai

# ---------- 1. API‑sleutel hard‑gecode ----------
API_KEY = "AIzaSyBExZA5Ty2cTyhIsu5iduRK0CeOdscU4iQ"   # <-- Vervang hier jouw sleutel!

# Configureer de library met de sleutel
genai.configure(api_key=API_KEY)

# ---------- 2. Model en chat ----------
model = genai.GenerativeModel("models/gemini-flash-latest")  # klein & snel
chat = model.start_chat(history=[])

# ---------- 3. Interactieve loop ----------
print("Welkom bij je mini‑Gemini bot!")
print("Typ 'afsluiten' of 'quit' om te stoppen.\n")

while True:
    try:
        user_input = input("Jij: ").strip()
    except (EOFError, KeyboardInterrupt):
        print("\nBye!")
        break

    if user_input.lower() in {"afsluiten", "quit", "exit"}:
        print("Tot ziens!")
        break

    try:
        response = chat.send_message(user_input)
        print(f"Gemini: {response.text}\n")
    except Exception as e:
        print(f"⚠️  Fout bij het aanroepen van Gemini: {e}\n")
# Out:
# Welkom bij je mini‑Gemini bot!
# Typ 'afsluiten' of 'quit' om te stoppen.
#
# Jij: hii
# Gemini: Hi there! How can I help you today?

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import google.generativeai as genai

API_KEY = "AIzaSyBExZA5Ty2cTyhIsu5iduRK0CeOdscU4iQ"
genai.configure(api_key=API_KEY)

# Gebruik een bestaand model
model = genai.GenerativeModel("models/gemini-flash-latest")
chat = model.start_chat(history=[])

print("Welkom bij je mini-Gemini bot!")
print("Typ 'afsluiten' of 'quit' om te stoppen.\n")

while True:
    try:
        user_input = input("Jij: ").strip()
    except (EOFError, KeyboardInterrupt):
        print("\nBye!")
        break

    if user_input.lower() in {"afsluiten", "quit", "exit"}:
        print("Tot ziens!")
        break

    try:
        response = chat.send_message(user_input)
        print(f"Gemini: {response.text}\n")
    except Exception as e:
        print(f"⚠️  Fout bij het aanroepen van Gemini: {e}\n")
# Out:
# Welkom bij je mini-Gemini bot!
# Typ 'afsluiten' of 'quit' om te stoppen.
# Jij:  hii
# Gemini: Hi! How can I help you today?
# Jij:  kan je Nederlands??
# Gemini: Jazeker! Ik spreek vloeiend Nederlands. Waarmee kan ik je helpen?
# Jij:  afsluiten
# Tot ziens!

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyBExZA5Ty2cTyhIsu5iduRK0CeOdscU4iQ")

for m in genai.list_models():
    print(m.name)
# Out:
# models/embedding-gecko-001
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# ...
